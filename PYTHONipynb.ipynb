# %% [markdown]
# <a href="https://colab.research.google.com/github/1mazin/1mazin/blob/main/PYTHONipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Input
name = input("what's your name?\n")
print(name)
# Out:
# what's your name?
# mehnaz
# mehnaz

# %%
#Multiple input
name,age= input("what's your name and age?\n").split()
print("name is {} and age is {}".format(name , age))
# Out:
# what's your name and age?
# Mehnaz 22
# name is Mehnaz and age is 22

# %%
#Multiple input using split
name,age=[int(x) for x in input("Write 2 numbers\n").split(",")]
print(name,age)
# Out:
# Write 2 numbers
# 45,77
# 45 77

# %%
# FOR PRINT STATEMENT :https://www.geeksforgeeks.org/python-output-using-print-function/?ref=lbp

# %%
##Use of flush

import time

count_seconds = 3
for i in reversed(range(count_seconds + 1)):
    if i > 0:
        print(i, end='>>>', flush = True)
        time.sleep(1)
    else:
        print('Start')
# Out:
# 3>>>2>>>1>>>Start

# %%
##Use of sep
a=12
b=12
c=2022
print(a,b,c,sep="-")
# Out:
# 12-12-2022

# %%
print("geeks",end="")
print("geeksforgeeks")
# Out:
# geeksgeeksforgeeks

# %%
# Print without newline in Python 3.x without using for loop

rollNo= [1, 2, 3, 4, 5, 6]

# using * symbol prints the list
# elements in a single line
print(*rollNo)
# Out:
# 1 2 3 4 5 6

# %%
import sys

sys.stdout.write("GeeksforGeeks ")
sys.stdout.write("is best website for coding!")
# Out:
# GeeksforGeeks is best website for coding!

# %% [markdown]
# Note :: The time complexity of the print() function is O(n)

# %%
# combining positional and keyword arguments
print('Number one portal is {0}, {1}, and {other}.'
	.format('Geeks', 'For', other ='Geeks'))

# using format() method with number
print("Geeks :{0:2d}, Portal :{1:8.2f}".
	format(12, 00.546))

# Changing positional argument
print("Second argument: {1:3d}, first one: {0:7.2f}".
	format(47.42, 11))

print("Geeks: {a:5d}, Portal: {p:8.2f}".
	format(a = 453, p = 59.058))
# Out:
# Number one portal is Geeks, For, and Geeks.
# Geeks :12, Portal :    0.55
# Second argument:  11, first one:   47.42
# Geeks:   453, Portal:    59.06

# %% [markdown]
# OPERATORS

# %%
a=25
b=4
print(a+b)
print(a-b)
print(a*b)
print(a/b)###always float
print(-5//2)
print(a**b)
# Out:
# 29
# 21
# 100
# 6.25
# -3
# 390625

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
##Comparison Operator<Arithmetic Operator

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a = 10
b = a
print(b)
b += a
print(b)
b -= a
print(b)
b *= a
print(b)
b <<= a
print(b)
# Out:
# 10
# 20
# 10
# 100
# 102400

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
##Ternary Operator
a=10
b=10
print("Both number are equal" if(a==b) else "a is greater then b" if(a>b) else "b is greater than a")
# Out:
# Both number are equal

# %%
# Python program to demonstrate ternary operator
a, b = 10, 20

print((lambda: b, lambda: a)[a < b]())


# Python program to demonstrate ternary operator
a, b = 10, 20

print({True: a, False: b} [a < b])
# Out:
# 10
# 10

# %%
//operator overloading-->Costumising existing operations..Not possible to change the number of operands of an operator
class A:
  def __init__(self,a,b):
    self.a=a
    self.b=b
  def __add__(self,other):
    return self.a+other.a,self.b+other.b

obj1=A(1,2)
obj2=A(3,7)
print(obj1+obj2)
# Out:
# (4, 9)
